# %%
import pandas as pd

# %%
covid=pd.read_csv('owid-covid-data.csv')

# %%
covid.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                 9.59             NaN           NaN                  37.746
# 1                 9.59             NaN           NaN                  37.746
# 2                 9.59             NaN           NaN                  37.746
# 3                 9.59             NaN           NaN                  37.746
# 4                 9.59             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#
# [5 rows x 64 columns]

# %%
#Looking at the shape
covid.shape
# Out:
# (119040, 64)

# %%
covid.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'new_tests', 'total_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'positive_rate', 'tests_per_case', 'tests_units', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated', 'total_boosters',
#        'new_vaccinations', 'new_vaccinations_smoothed',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'total_boosters_per_hundred',
#        'new_vaccinations_smoothed_per_million', 'stringency_index',
#        'population', 'population_density', 'median_age', 'aged_65_older',
#        'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cardiovasc_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_thousand',
#        'life_expectancy', 'human_development_index',
#        'excess_mortality_cumulative_absolute', 'excess_mortality_cumulative',
#        'excess_mortality'],
#       dtype='object')

# %%
#Looking at the different location
covid["location"].value_counts()
# Out:
# Mexico              633
# Argentina           633
# Peru                633
# Thailand            630
# Taiwan              618
#                    ...
# Falkland Islands     67
# Tokelau              57
# Niue                 43
# Palau                34
# Turkmenistan          1
# Name: location, Length: 233, dtype: int64

# %%
#Looking at categorical column
covid.describe(include='O')
# Out:
#        iso_code continent location        date      tests_units
# count    119040    113606   119040      119040            63203
# unique      233         6      233         633                4
# top         MEX    Africa   Mexico  2021-07-23  tests performed
# freq        633     30217      633         229            39669

# %%
#Looking if any columns have null values
covid.isna().any()
# Out:
# iso_code                                False
# continent                                True
# location                                False
# date                                    False
# total_cases                              True
#                                         ...
# life_expectancy                          True
# human_development_index                  True
# excess_mortality_cumulative_absolute     True
# excess_mortality_cumulative              True
# excess_mortality                         True
# Length: 64, dtype: bool

# %%
#Getting the sum of null values across all columns
covid.isna().sum()
# Out:
# iso_code                                     0
# continent                                 5434
# location                                     0
# date                                         0
# total_cases                               5945
#                                          ...
# life_expectancy                           6115
# human_development_index                  13484
# excess_mortality_cumulative_absolute    114908
# excess_mortality_cumulative             114908
# excess_mortality                        114833
# Length: 64, dtype: int64

# %%
#Getting the cases of india
india_case=covid[covid["location"]=="India"]

# %%
india_case.head()
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 49218      IND      Asia    India  2020-01-30          1.0        1.0
# 49219      IND      Asia    India  2020-01-31          1.0        0.0
# 49220      IND      Asia    India  2020-02-01          1.0        0.0
# 49221      IND      Asia    India  2020-02-02          2.0        1.0
# 49222      IND      Asia    India  2020-02-03          3.0        1.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 49218                 NaN           NaN         NaN                  NaN  ...
# 49219                 NaN           NaN         NaN                  NaN  ...
# 49220                 NaN           NaN         NaN                  NaN  ...
# 49221                 NaN           NaN         NaN                  NaN  ...
# 49222                 NaN           NaN         NaN                  NaN  ...
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 49218                10.39             1.9          20.6
# 49219                10.39             1.9          20.6
# 49220                10.39             1.9          20.6
# 49221                10.39             1.9          20.6
# 49222                10.39             1.9          20.6
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 49218                   59.55                        0.53            69.66
# 49219                   59.55                        0.53            69.66
# 49220                   59.55                        0.53            69.66
# 49221                   59.55                        0.53            69.66
# 49222                   59.55                        0.53            69.66
#
#        human_development_index  excess_mortality_cumulative_absolute  \
# 49218                    0.645                                   NaN
# 49219                    0.645                                   NaN
# 49220                    0.645                                   NaN
# 49221                    0.645                                   NaN
# 49222                    0.645                                   NaN
#
#        excess_mortality_cumulative  excess_mortality
# 49218                          NaN               NaN
# 49219                          NaN               NaN
# 49220                          NaN               NaN
# 49221                          NaN               NaN
# 49222                          NaN               NaN
#
# [5 rows x 64 columns]

# %%
india_case.tail()
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 49817      IND      Asia    India  2021-09-20   33504534.0    26115.0
# 49818      IND      Asia    India  2021-09-21   33531498.0    26964.0
# 49819      IND      Asia    India  2021-09-22   33563421.0    31923.0
# 49820      IND      Asia    India  2021-09-23   33594803.0    31382.0
# 49821      IND      Asia    India  2021-09-24   33624419.0    29616.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 49817           30707.857      445385.0       252.0              310.286  ...
# 49818           30677.571      445768.0       383.0              324.429  ...
# 49819           30870.857      446050.0       282.0              303.143  ...
# 49820           30439.286      446368.0       318.0              302.857  ...
# 49821           29575.571      446658.0       290.0              304.143  ...
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 49817                10.39             1.9          20.6
# 49818                10.39             1.9          20.6
# 49819                10.39             1.9          20.6
# 49820                10.39             1.9          20.6
# 49821                10.39             1.9          20.6
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 49817                   59.55                        0.53            69.66
# 49818                   59.55                        0.53            69.66
# 49819                   59.55                        0.53            69.66
# 49820                   59.55                        0.53            69.66
# 49821                   59.55                        0.53            69.66
#
#        human_development_index  excess_mortality_cumulative_absolute  \
# 49817                    0.645                                   NaN
# 49818                    0.645                                   NaN
# 49819                    0.645                                   NaN
# 49820                    0.645                                   NaN
# 49821                    0.645                                   NaN
#
#        excess_mortality_cumulative  excess_mortality
# 49817                          NaN               NaN
# 49818                          NaN               NaN
# 49819                          NaN               NaN
# 49820                          NaN               NaN
# 49821                          NaN               NaN
#
# [5 rows x 64 columns]

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
#Total Cases Per day
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="total_cases",data=india_case)
plt.show()

# %%
india_last_5_days=india_case.tail()

# %%
#Last 5 day case
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="total_cases",data=india_last_5_days)
plt.show()

# %%
#Total Test Per day
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="total_tests",data=india_case)
plt.show()

# %%
#Last 5 day testing
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x="date",y="total_tests",data=india_last_5_days)
plt.show()

# %%
#Last Day Cases
last_day_cases=covid[covid["date"]=="2021-09-24"]
last_day_cases
# Out:
#         iso_code continent     location        date  total_cases  new_cases  \
# 90           AFG      Asia  Afghanistan  2020-05-24      10668.0      716.0
# 680     OWID_AFR       NaN       Africa  2020-05-24     111607.0     4122.0
# 1258         ALB    Europe      Albania  2020-05-24        998.0        9.0
# 1836         DZA    Africa      Algeria  2020-05-24       8306.0      193.0
# 2408         AND    Europe      Andorra  2020-05-24        762.0        0.0
# ...          ...       ...          ...         ...          ...        ...
# 116113       VNM      Asia      Vietnam  2020-05-24        325.0        0.0
# 116908  OWID_WRL       NaN        World  2020-05-24    5422534.0    94545.0
# 117441       YEM      Asia        Yemen  2020-05-24        222.0       10.0
# 117997       ZMB    Africa       Zambia  2020-05-24        920.0        0.0
# 118551       ZWE    Africa     Zimbabwe  2020-05-24         56.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 90                 576.143         222.0         7.0                7.571
# 680               3860.000        3354.0        99.0               85.143
# 1258                 7.429          32.0         1.0                0.143
# 1836               183.857         600.0         8.0                7.429
# 2408                 0.143          51.0         0.0                0.000
# ...                    ...           ...         ...                  ...
# 116113               0.714           NaN         NaN                0.000
# 116908          100015.857      361637.0      3483.0             4718.286
# 117441              13.429          42.0         3.0                3.143
# 117997              23.857           7.0         0.0                0.000
# 118551               1.714           4.0         0.0                0.000
#
#         ...  diabetes_prevalence  female_smokers  male_smokers  \
# 90      ...                 9.59             NaN           NaN
# 680     ...                  NaN             NaN           NaN
# 1258    ...                10.08           7.100        51.200
# 1836    ...                 6.73           0.700        30.400
# 2408    ...                 7.97          29.000        37.800
# ...     ...                  ...             ...           ...
# 116113  ...                 6.00           1.000        45.900
# 116908  ...                 8.51           6.434        34.635
# 117441  ...                 5.35           7.600        29.200
# 117997  ...                 3.94           3.100        24.700
# 118551  ...                 1.82           1.600        30.700
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 90                      37.746                       0.500            64.83
# 680                        NaN                         NaN              NaN
# 1258                       NaN                       2.890            78.57
# 1836                    83.741                       1.900            76.88
# 2408                       NaN                         NaN            83.73
# ...                        ...                         ...              ...
# 116113                  85.847                       2.600            75.40
# 116908                  60.130                       2.705            72.58
# 117441                  49.542                       0.700            66.12
# 117997                  13.938                       2.000            63.89
# 118551                  36.791                       1.700            61.49
#
#         human_development_index  excess_mortality_cumulative_absolute  \
# 90                        0.511                                   NaN
# 680                         NaN                                   NaN
# 1258                      0.795                                   NaN
# 1836                      0.748                                   NaN
# 2408                      0.868                                   NaN
# ...                         ...                                   ...
# 116113                    0.704                                   NaN
# 116908                    0.737                                   NaN
# 117441                    0.470                                   NaN
# 117997                    0.584                                   NaN
# 118551                    0.571                                   NaN
#
#         excess_mortality_cumulative  excess_mortality
# 90                              NaN               NaN
# 680                             NaN               NaN
# 1258                            NaN               NaN
# 1836                            NaN               NaN
# 2408                            NaN               NaN
# ...                             ...               ...
# 116113                          NaN               NaN
# 116908                          NaN               NaN
# 117441                          NaN               NaN
# 117997                          NaN               NaN
# 118551                          NaN               NaN
#
# [195 rows x 64 columns]

# %%
#sorting data wrt total case
max_case_country=last_day_cases.sort_values(by="total_cases",ascending=False)
max_case_country
# Out:
#         iso_code      continent          location        date  total_cases  \
# 116908  OWID_WRL            NaN             World  2020-05-24    5422534.0
# 78815   OWID_NAM            NaN     North America  2020-05-24    1848144.0
# 35888   OWID_EUR            NaN            Europe  2020-05-24    1845878.0
# 112935       USA  North America     United States  2020-05-24    1652805.0
# 36499   OWID_EUN            NaN    European Union  2020-05-24    1129673.0
# ...          ...            ...               ...         ...          ...
# 114942       VAT         Europe           Vatican  2020-05-24         12.0
# 94503        SYC         Africa        Seychelles  2020-05-24         11.0
# 102525       SUR  South America          Suriname  2020-05-24         11.0
# 83672        PNG        Oceania  Papua New Guinea  2020-05-24          8.0
# 60774        LSO         Africa           Lesotho  2020-05-24          2.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 116908    94545.0          100015.857      361637.0      3483.0
# 78815     25765.0           27462.429      117144.0       969.0
# 35888     14197.0           17299.143      168872.0       734.0
# 112935    20306.0           22399.571      101213.0       640.0
# 36499      2637.0            4436.429      125528.0       171.0
# ...           ...                 ...           ...         ...
# 114942        0.0               0.000           NaN         NaN
# 94503         0.0               0.000           NaN         NaN
# 102525        0.0               0.143           1.0         0.0
# 83672         0.0               0.000           NaN         NaN
# 60774         0.0               0.143           NaN         NaN
#
#         new_deaths_smoothed  ...  diabetes_prevalence  female_smokers  \
# 116908             4718.286  ...                 8.51           6.434
# 78815              1619.857  ...                  NaN             NaN
# 35888              1008.857  ...                  NaN             NaN
# 112935             1187.286  ...                10.79          19.100
# 36499               540.429  ...                  NaN             NaN
# ...                     ...  ...                  ...             ...
# 114942                0.000  ...                  NaN             NaN
# 94503                 0.000  ...                10.55           7.100
# 102525                0.000  ...                12.54           7.400
# 83672                 0.000  ...                17.65          23.500
# 60774                 0.000  ...                 3.94           0.400
#
#         male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 116908        34.635                  60.130                       2.705
# 78815            NaN                     NaN                         NaN
# 35888            NaN                     NaN                         NaN
# 112935        24.600                     NaN                       2.770
# 36499            NaN                     NaN                         NaN
# ...              ...                     ...                         ...
# 114942           NaN                     NaN                         NaN
# 94503         35.700                     NaN                       3.600
# 102525        42.900                  67.779                       3.100
# 83672         48.800                     NaN                         NaN
# 60774         53.900                   2.117                         NaN
#
#         life_expectancy  human_development_index  \
# 116908            72.58                    0.737
# 78815               NaN                      NaN
# 35888               NaN                      NaN
# 112935            78.86                    0.926
# 36499               NaN                      NaN
# ...                 ...                      ...
# 114942            75.12                      NaN
# 94503             73.40                    0.796
# 102525            71.68                    0.738
# 83672             64.50                    0.555
# 60774             54.33                    0.527
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 116908                                   NaN                          NaN
# 78815                                    NaN                          NaN
# 35888                                    NaN                          NaN
# 112935                              115490.3                         9.43
# 36499                                    NaN                          NaN
# ...                                      ...                          ...
# 114942                                   NaN                          NaN
# 94503                                    NaN                          NaN
# 102525                                   NaN                          NaN
# 83672                                    NaN                          NaN
# 60774                                    NaN                          NaN
#
#         excess_mortality
# 116908               NaN
# 78815                NaN
# 35888                NaN
# 112935             15.14
# 36499                NaN
# ...                  ...
# 114942               NaN
# 94503                NaN
# 102525               NaN
# 83672                NaN
# 60774                NaN
#
# [195 rows x 64 columns]

# %%
max_case_country[1:6]
# Out:
#         iso_code      continent        location        date  total_cases  \
# 78815   OWID_NAM            NaN   North America  2020-05-24    1848144.0
# 35888   OWID_EUR            NaN          Europe  2020-05-24    1845878.0
# 112935       USA  North America   United States  2020-05-24    1652805.0
# 36499   OWID_EUN            NaN  European Union  2020-05-24    1129673.0
# 5754    OWID_ASI            NaN            Asia  2020-05-24     961206.0
#
#         new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 78815     25765.0           27462.429      117144.0       969.0
# 35888     14197.0           17299.143      168872.0       734.0
# 112935    20306.0           22399.571      101213.0       640.0
# 36499      2637.0            4436.429      125528.0       171.0
# 5754      24031.0           23169.000       27510.0       389.0
#
#         new_deaths_smoothed  ...  diabetes_prevalence  female_smokers  \
# 78815              1619.857  ...                  NaN             NaN
# 35888              1008.857  ...                  NaN             NaN
# 112935             1187.286  ...                10.79            19.1
# 36499               540.429  ...                  NaN             NaN
# 5754                388.000  ...                  NaN             NaN
#
#         male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 78815            NaN                     NaN                         NaN
# 35888            NaN                     NaN                         NaN
# 112935          24.6                     NaN                        2.77
# 36499            NaN                     NaN                         NaN
# 5754             NaN                     NaN                         NaN
#
#         life_expectancy  human_development_index  \
# 78815               NaN                      NaN
# 35888               NaN                      NaN
# 112935            78.86                    0.926
# 36499               NaN                      NaN
# 5754                NaN                      NaN
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 78815                                    NaN                          NaN
# 35888                                    NaN                          NaN
# 112935                              115490.3                         9.43
# 36499                                    NaN                          NaN
# 5754                                     NaN                          NaN
#
#         excess_mortality
# 78815                NaN
# 35888                NaN
# 112935             15.14
# 36499                NaN
# 5754                 NaN
#
# [5 rows x 64 columns]

# %%
sns.barplot(x="location",y="total_cases",data=max_case_country[1:6],hue="location")
# Out:
# <AxesSubplot:xlabel='location', ylabel='total_cases'>

# %%
india_case.head()
# Out:
#       iso_code continent location        date  total_cases  new_cases  \
# 49218      IND      Asia    India  2020-01-30          1.0        1.0
# 49219      IND      Asia    India  2020-01-31          1.0        0.0
# 49220      IND      Asia    India  2020-02-01          1.0        0.0
# 49221      IND      Asia    India  2020-02-02          2.0        1.0
# 49222      IND      Asia    India  2020-02-03          3.0        1.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 49218                 NaN           NaN         NaN                  NaN  ...
# 49219                 NaN           NaN         NaN                  NaN  ...
# 49220                 NaN           NaN         NaN                  NaN  ...
# 49221                 NaN           NaN         NaN                  NaN  ...
# 49222                 NaN           NaN         NaN                  NaN  ...
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 49218                10.39             1.9          20.6
# 49219                10.39             1.9          20.6
# 49220                10.39             1.9          20.6
# 49221                10.39             1.9          20.6
# 49222                10.39             1.9          20.6
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 49218                   59.55                        0.53            69.66
# 49219                   59.55                        0.53            69.66
# 49220                   59.55                        0.53            69.66
# 49221                   59.55                        0.53            69.66
# 49222                   59.55                        0.53            69.66
#
#        human_development_index  excess_mortality_cumulative_absolute  \
# 49218                    0.645                                   NaN
# 49219                    0.645                                   NaN
# 49220                    0.645                                   NaN
# 49221                    0.645                                   NaN
# 49222                    0.645                                   NaN
#
#        excess_mortality_cumulative  excess_mortality
# 49218                          NaN               NaN
# 49219                          NaN               NaN
# 49220                          NaN               NaN
# 49221                          NaN               NaN
# 49222                          NaN               NaN
#
# [5 rows x 64 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
import datetime as dt
india_case['date']=pd.to_datetime(india_case['date'])
india_case.head()
# Out:
# C:\Users\bhavye\AppData\Local\Temp/ipykernel_17656/2423233094.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   india_case['date']=pd.to_datetime(india_case['date'])
#       iso_code continent location       date  total_cases  new_cases  \
# 49218      IND      Asia    India 2020-01-30          1.0        1.0
# 49219      IND      Asia    India 2020-01-31          1.0        0.0
# 49220      IND      Asia    India 2020-02-01          1.0        0.0
# 49221      IND      Asia    India 2020-02-02          2.0        1.0
# 49222      IND      Asia    India 2020-02-03          3.0        1.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 49218                 NaN           NaN         NaN                  NaN  ...
# 49219                 NaN           NaN         NaN                  NaN  ...
# 49220                 NaN           NaN         NaN                  NaN  ...
# 49221                 NaN           NaN         NaN                  NaN  ...
# 49222                 NaN           NaN         NaN                  NaN  ...
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 49218                10.39             1.9          20.6
# 49219                10.39             1.9          20.6
# 49220                10.39             1.9          20.6
# 49221                10.39             1.9          20.6
# 49222                10.39             1.9          20.6
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 49218                   59.55                        0.53            69.66
# 49219                   59.55                        0.53            69.66
# 49220                   59.55                        0.53            69.66
# 49221                   59.55                        0.53            69.66
# 49222                   59.55                        0.53            69.66
#
#        human_development_index  excess_mortality_cumulative_absolute  \
# 49218                    0.645                                   NaN
# 49219                    0.645                                   NaN
# 49220                    0.645                                   NaN
# 49221                    0.645                                   NaN
# 49222                    0.645                                   NaN
#
#        excess_mortality_cumulative  excess_mortality
# 49218                          NaN               NaN
# 49219                          NaN               NaN
# 49220                          NaN               NaN
# 49221                          NaN               NaN
# 49222                          NaN               NaN
#
# [5 rows x 64 columns]

# %%
india_case['date']=india_case['date'].map(dt.datetime.toordinal)
india_case.head()
# Out:
# C:\Users\bhavye\AppData\Local\Temp/ipykernel_17656/2717184129.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   india_case['date']=india_case['date'].map(dt.datetime.toordinal)
#       iso_code continent location    date  total_cases  new_cases  \
# 49218      IND      Asia    India  737454          1.0        1.0
# 49219      IND      Asia    India  737455          1.0        0.0
# 49220      IND      Asia    India  737456          1.0        0.0
# 49221      IND      Asia    India  737457          2.0        1.0
# 49222      IND      Asia    India  737458          3.0        1.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 49218                 NaN           NaN         NaN                  NaN  ...
# 49219                 NaN           NaN         NaN                  NaN  ...
# 49220                 NaN           NaN         NaN                  NaN  ...
# 49221                 NaN           NaN         NaN                  NaN  ...
# 49222                 NaN           NaN         NaN                  NaN  ...
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 49218                10.39             1.9          20.6
# 49219                10.39             1.9          20.6
# 49220                10.39             1.9          20.6
# 49221                10.39             1.9          20.6
# 49222                10.39             1.9          20.6
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 49218                   59.55                        0.53            69.66
# 49219                   59.55                        0.53            69.66
# 49220                   59.55                        0.53            69.66
# 49221                   59.55                        0.53            69.66
# 49222                   59.55                        0.53            69.66
#
#        human_development_index  excess_mortality_cumulative_absolute  \
# 49218                    0.645                                   NaN
# 49219                    0.645                                   NaN
# 49220                    0.645                                   NaN
# 49221                    0.645                                   NaN
# 49222                    0.645                                   NaN
#
#        excess_mortality_cumulative  excess_mortality
# 49218                          NaN               NaN
# 49219                          NaN               NaN
# 49220                          NaN               NaN
# 49221                          NaN               NaN
# 49222                          NaN               NaN
#
# [5 rows x 64 columns]

# %%
x=india_case['date']
y=india_case['total_cases']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
#linear regression
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
import numpy as np
lr.fit(np.array(x_train).reshape(-1,1),np.array(y_train).reshape(-1,1))
# Out:
# LinearRegression()

# %%
india_case.tail()
# Out:
#       iso_code continent location    date  total_cases  new_cases  \
# 49817      IND      Asia    India  738053   33504534.0    26115.0
# 49818      IND      Asia    India  738054   33531498.0    26964.0
# 49819      IND      Asia    India  738055   33563421.0    31923.0
# 49820      IND      Asia    India  738056   33594803.0    31382.0
# 49821      IND      Asia    India  738057   33624419.0    29616.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 49817           30707.857      445385.0       252.0              310.286  ...
# 49818           30677.571      445768.0       383.0              324.429  ...
# 49819           30870.857      446050.0       282.0              303.143  ...
# 49820           30439.286      446368.0       318.0              302.857  ...
# 49821           29575.571      446658.0       290.0              304.143  ...
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 49817                10.39             1.9          20.6
# 49818                10.39             1.9          20.6
# 49819                10.39             1.9          20.6
# 49820                10.39             1.9          20.6
# 49821                10.39             1.9          20.6
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 49817                   59.55                        0.53            69.66
# 49818                   59.55                        0.53            69.66
# 49819                   59.55                        0.53            69.66
# 49820                   59.55                        0.53            69.66
# 49821                   59.55                        0.53            69.66
#
#        human_development_index  excess_mortality_cumulative_absolute  \
# 49817                    0.645                                   NaN
# 49818                    0.645                                   NaN
# 49819                    0.645                                   NaN
# 49820                    0.645                                   NaN
# 49821                    0.645                                   NaN
#
#        excess_mortality_cumulative  excess_mortality
# 49817                          NaN               NaN
# 49818                          NaN               NaN
# 49819                          NaN               NaN
# 49820                          NaN               NaN
# 49821                          NaN               NaN
#
# [5 rows x 64 columns]

# %%
y_pred=lr.predict(np.array(x_test).reshape(-1,1))

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(x_test,y_pred)
# Out:
# 235618543032574.03

# %%
lr.predict(np.array([[738057]]))
# Out:
# array([[30129230.82875061]])
